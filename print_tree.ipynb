# %%
import os
from pathlib import Path

def print_and_collect_tree(directory, ignore_patterns=None, ignore_extensions=None, prefix=""):
    # Initialize an empty list to collect all lines of output
    output_lines = []
    
    # Default patterns to ignore (directories and files)
    if ignore_patterns is None:
        ignore_patterns = [
            '__pycache__', '.egg-info', 'dist', 'build', 'venv',
            '.git', '.vscode', '.lprof', '.ipynb_checkpoints',
            'Pol_Hom.afdesign', 'Pol_Hom_backup.afdesign',
            'src - Copia_BU_for_modularization',  # Ignore the backup directory
            'OLD_notebooks', 'figures', 'temporary_for_bootstrapsandsuch', 'old_stuff', 'affinity_files'
        ]
    
    # Default extensions to ignore
    if ignore_extensions is None:
        ignore_extensions = ['.json', '.npz']
    
    try:
        items = sorted(os.listdir(directory))
    except PermissionError:
        return output_lines

    # Enhanced filtering that checks both patterns and file extensions
    filtered_items = []
    for item in items:
        # Check if item exactly matches any pattern or contains any pattern
        if item in ignore_patterns or any(pattern in item for pattern in ignore_patterns):
            continue
            
        full_path = os.path.join(directory, item)
        if os.path.isfile(full_path):
            file_extension = os.path.splitext(item)[1].lower()
            if file_extension in ignore_extensions:
                continue
                
        filtered_items.append(item)
    
    # Process and collect the filtered items
    for index, item in enumerate(filtered_items):
        path = os.path.join(directory, item)
        is_last = index == len(filtered_items) - 1
        
        # Create the line with proper formatting for both console and Markdown
        line = f"{prefix}{'└──' if is_last else '├──'} {item}"
        print(line)  # Print to console
        output_lines.append(line)  # Collect for file
        
        # Recursively process subdirectories
        if os.path.isdir(path):
            extension = "    " if is_last else "│   "
            subdirectory_lines = print_and_collect_tree(path, ignore_patterns, ignore_extensions, prefix + extension)
            output_lines.extend(subdirectory_lines)
    
    return output_lines

if __name__ == "__main__":
    print("Project Structure:")
    
    # Collect all lines of the tree structure
    tree_lines = ["# Project Structure\n"]  # Start with a Markdown header
    tree_lines.extend(print_and_collect_tree("."))
    
    # Save to Markdown file
    with open("tree.md", "w", encoding="utf-8") as f:
        # Use code block formatting for better rendering in Markdown
        f.write("```\n")  # Start code block
        f.write("\n".join(tree_lines))
        f.write("\n```")  # End code block
    
    print("\nTree structure has been saved to 'tree.md'")
# Out:
# Project Structure:
# ├── Experiments
# │   ├── Experiment_1
# │   │   ├── config.json
# │   │   ├── param_grid.json
# │   │   ├── run_single_job.py
# │   │   └── runme.sh
# │   └── Experiment_2_BIG
# │       ├── config.json
# │       ├── param_grid.json
# │       ├── run_single_job.py
# │       └── runme.sh
# ├── README.md
# ├── config
# │   └── PARAMS.json
# ├── potential literature
# ├── print_tree.ipynb
# ├── results
# │   ├── closest_eps04.npz
# │   ├── closest_eps04_config.json
# │   ├── diverse_engagement_eps04.npz
# │   ├── diverse_engagement_eps04_config.json
# │   ├── engagement_eps04_alpha1.npz
# │   ├── engagement_eps04_alpha1_config.json
# │   ├── engagement_eps04_alpha2.npz
# │   ├── engagement_eps04_alpha2_config.json
# │   ├── eps010_closest.npz
# │   ├── eps010_closest_config.json
# │   ├── eps010_diverse_engagement.npz
# │   ├── eps010_diverse_engagement_config.json
# │   ├── eps010_engagement.npz
# │   ├── eps010_engagement_config.json
# │   ├── eps010_random.npz
# │   ├── eps010_random_config.json
# │   ├── eps013_closest.npz
# │   ├── eps013_closest_config.json
# │   ├── eps013_diverse_engagement.npz
# │   ├── eps013_diverse_engagement_config.json
# │   ├── eps013_engagement.npz
# │   ├── eps013_engagement_config.json
# │   ├── eps013_random.npz
# │   ├── eps013_random_config.json
# │   ├── eps017_closest.npz
# │   ├── eps017_closest_config.json
# │   ├── eps017_diverse_engagement.npz
# │   ├── eps017_diverse_engagement_config.json
# │   ├── eps017_engagement.npz
# │   ├── eps017_engagement_config.json
# │   ├── eps017_random.npz
# │   ├── eps017_random_config.json
# │   ├── eps020_closest.npz
# │   ├── eps020_closest_config.json
# │   ├── eps020_diverse_engagement.npz
# │   ├── eps020_diverse_engagement_config.json
# │   ├── eps020_engagement.npz
# │   ├── eps020_engagement_config.json
# │   ├── eps020_random.npz
# │   ├── eps020_random_config.json
# │   ├── eps023_closest.npz
# │   ├── eps023_closest_config.json
# │   ├── eps023_diverse_engagement.npz
# │   ├── eps023_diverse_engagement_config.json
# │   ├── eps023_engagement.npz
# │   ├── eps023_engagement_config.json
# │   ├── eps023_random.npz
# │   ├── eps023_random_config.json
# │   ├── eps027_closest.npz
# │   ├── eps027_closest_config.json
# │   ├── eps027_diverse_engagement.npz
# │   ├── eps027_diverse_engagement_config.json
# │   ├── eps027_engagement.npz
# │   ├── eps027_engagement_config.json
# │   ├── eps027_random.npz
# │   ├── eps027_random_config.json
# │   ├── eps030_closest.npz
# │   ├── eps030_closest_config.json
# │   ├── eps030_diverse_engagement.npz
# │   ├── eps030_diverse_engagement_config.json
# │   ├── eps030_engagement.npz
# │   ├── eps030_engagement_config.json
# │   ├── eps030_random.npz
# │   ├── eps030_random_config.json
# │   ├── eps033_closest.npz
# │   ├── eps033_closest_config.json
# │   ├── eps033_diverse_engagement.npz
# │   ├── eps033_diverse_engagement_config.json
# │   ├── eps033_engagement.npz
# │   ├── eps033_engagement_config.json
# │   ├── eps033_random.npz
# │   ├── eps033_random_config.json
# │   ├── eps037_closest.npz
# │   ├── eps037_closest_config.json
# │   ├── eps037_diverse_engagement.npz
# │   ├── eps037_diverse_engagement_config.json
# │   ├── eps037_engagement.npz
# │   ├── eps037_engagement_config.json
# │   ├── eps037_random.npz
# │   ├── eps037_random_config.json
# │   ├── eps040_closest.npz
# │   ├── eps040_closest_config.json
# │   ├── eps040_diverse_engagement.npz
# │   ├── eps040_diverse_engagement_config.json
# │   ├── eps040_engagement.npz
# │   ├── eps040_engagement_config.json
# │   ├── eps040_random.npz
# │   ├── eps040_random_config.json
# │   ├── narrative_eps04_target05.npz
# │   ├── narrative_eps04_target05_config.json
# │   ├── narrative_eps04_target1.npz
# │   ├── narrative_eps04_target1_config.json
# │   ├── random_eps02.npz
# │   ├── random_eps02_config.json
# │   ├── random_eps04.npz
# │   ├── random_eps04_config.json
# │   ├── temp.npz
# │   └── temp_config.json
# ├── runme.ipynb
# ├── src
# │   ├── analysis.py
# │   ├── graphs.py
# │   ├── metrics.py
# │   ├── models
# │   │   └── BCM.py
# │   ├── rankers
# │   │   ├── closest.py
# │   │   ├── diverse_engagement.py
# │   │   ├── engagement.py
# │   │   ├── evil.py
# │   │   ├── narrative.py
# │   │   └── random.py
# │   └── simulation.py
# ├── test.ipynb
# └── test_.ipynb
#
# Tree structure has been saved to 'tree.md'
